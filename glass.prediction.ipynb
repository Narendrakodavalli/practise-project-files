# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing data set

# %%
df=pd.read_csv('glass.csv')

# %%
df
# Out:
#        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00.1  1.1
# 0      2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00    0.00    1
# 1      3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00    0.00    1
# 2      4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00    0.00    1
# 3      5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00    0.00    1
# 4      6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00    0.26    1
# ..   ...      ...    ...   ...   ...    ...   ...   ...   ...     ...  ...
# 208  210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06    0.00    7
# 209  211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59    0.00    7
# 210  212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64    0.00    7
# 211  213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57    0.00    7
# 212  214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67    0.00    7
#
# [213 rows x 11 columns]

# %%
#checking null values
df.isnull().sum()
# Out:
# 1          0
# 1.52101    0
# 13.64      0
# 4.49       0
# 1.10       0
# 71.78      0
# 0.06       0
# 8.75       0
# 0.00       0
# 0.00.1     0
# 1.1        0
# dtype: int64

# %% [markdown]
# The dataset doesnot contain any missing values..

# %%
#checking datatypes
df.dtypes
# Out:
# 1            int64
# 1.52101    float64
# 13.64      float64
# 4.49       float64
# 1.10       float64
# 71.78      float64
# 0.06       float64
# 8.75       float64
# 0.00       float64
# 0.00.1     float64
# 1.1          int64
# dtype: object

# %% [markdown]
# Renaming the columns

# %% [markdown]
# 1.	 Id number: 1 to 214
# 2.	 RI: refractive index
# 3.	Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)
# 4.	Mg: Magnesium
# 5.	Al: Aluminum
# 6.	Si: Silicon
# 7.	K: Potassium
# 8.	Ca: Calcium
# 9.	Ba: Barium
# 10.	Fe: Iron
# 11.	Type of glass: (class attribute)

# %%
df=df.rename(columns={'1':'Id number','1.52101':'RI','13.64':'Na','4.49':'Mg','1.10':'Al','71.78':'Si','0.06':'K',
                      '8.75':'Ca','0.00':'Ba','0.00.1':'Fe','1.1':'Type of glass'})

# %%
df
# Out:
#      Id number       RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  \
# 0            2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00
# 1            3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00
# 2            4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00
# 3            5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00
# 4            6  1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26
# ..         ...      ...    ...   ...   ...    ...   ...   ...   ...   ...
# 208        210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00
# 209        211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00
# 210        212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00
# 211        213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00
# 212        214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.00
#
#      Type of glass
# 0                1
# 1                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id number      213 non-null    int64
#  1   RI             213 non-null    float64
#  2   Na             213 non-null    float64
#  3   Mg             213 non-null    float64
#  4   Al             213 non-null    float64
#  5   Si             213 non-null    float64
#  6   K              213 non-null    float64
#  7   Ca             213 non-null    float64
#  8   Ba             213 non-null    float64
#  9   Fe             213 non-null    float64
#  10  Type of glass  213 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.4 KB

# %% [markdown]
# # EDA EXPLORATARY DATA ANALYSIS

# %%
#check the list of counts on target
df["Type of glass"].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %%
#checking no of unique values in target column
df['Type of glass'].value_counts()
# Out:
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type of glass, dtype: int64

# %% [markdown]
# They are 6 categories in target(quality) column namely '1','2','3','5','6' and '7'.
# 1,2,3 are window type and 5,6,7 are non window type glass

# %%
#Number of values for each quality
sns.catplot(x='Type of glass', data=df, kind='count')

# %%
#Statastical measures of dataset
df.describe()
# Out:
#         Id number          RI          Na          Mg          Al          Si  \
# count  213.000000  213.000000  213.000000  213.000000  213.000000  213.000000
# mean   108.000000    1.518353   13.406761    2.676056    1.446526   72.655023
# std     61.631972    0.003039    0.818371    1.440453    0.499882    0.774052
# min      2.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     55.000000    1.516520   12.900000    2.090000    1.190000   72.280000
# 50%    108.000000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    161.000000    1.519150   13.830000    3.600000    1.630000   73.090000
# max    214.000000    1.533930   17.380000    3.980000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe  Type of glass
# count  213.000000  213.000000  213.000000  213.000000     213.000000
# mean     0.499108    8.957934    0.175869    0.057277       2.788732
# ...

# %% [markdown]
# The statistical information of numerical columns..The summary of dataset looks perfect since no negative / invalid values are present. we can observe from dataet
# 1)The count of all columns are same and no missisng values in dataset.
# 2)In the columns RI,Na,AI,Ca,fe and ba mean is greater than median means data is right skeweed.The columns Mg,si,k man is less tha median data is right skewed.
# 3)The columns Na,K,Ca,Ba,Fe the outliers are present.

# %%
#comparing fixed Type of glass vs RI
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='RI', data=df)
plt.show()

# %%
#comparing fixed Type of glass vs Na
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='Na', data=df)
plt.show()

# %%
#comparing fixed Type of glass vs AI
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='Al', data=df)
plt.show()

# %%
#comparing fixed Type of glass vs Si
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='Si', data=df)
plt.show()

# %%
#comparing fixed Type of glass vs mg
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='Mg', data=df)
plt.show()

# %%
#comparing fixed Type of glass vs K
plot=plt.figure(figsize=(6,6))
sns.barplot(x='Type of glass', y='K', data=df)
plt.show()

# %%
#lets check how data hss been distributed in remaing column-checking the column with inthe column
plt.figure(figsize=(20,15), facecolor= "white")
plotnumber = 1#iteration or index value
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3, plotnumber)#subplot is used to plot diff plot on single image
        sns.distplot(df[col], color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation= 0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# 1)RI,Na,Ca,Ai,Si follows normal distribution.
# 2)Fe,Ba,k has right skewed means positiv distribution.
# 3)Mg has left skewned means neative distribution

# %% [markdown]
# Bivirate analysis--COMPARING ONE COLUMN WITH ANOTHER COLUMN

# %%
plt.title("Comparing betw RI and Na")
sns.scatterplot(x="RI", y="Na", data=df, hue="Type of glass", palette="bright")
plt.show()

# %% [markdown]
# when Na is high and Ri is low non window type glass also high

# %%
plt.title("Comparing betw RI and Fe")
sns.scatterplot(x="RI", y="Fe", data=df, hue="Type of glass", palette="bright")
plt.show()

# %%
sns.pairplot(df, hue="Type of glass", palette="Dark2")
plt.show()

# %%
df=df.drop(columns='Id number', axis=1)

# %% [markdown]
# Detecting the outliers

# %%
plt.figure(figsize=(20,15), facecolor= "white")
plotnumber = 1#iteration or index value
for col in df:
    if plotnumber<=12:
        ax=plt.subplot(4,3, plotnumber)#subplot is used to plot diff plot on single image
        sns.boxplot(df[col], color="pink")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation= 0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# there ia s huge outliers in RI,Na,Ba,Ca,Fe,AL,SI and K

# %%
from scipy.stats import zscore
out_col=df[['RI','Na','Ba','Ca','Fe','Al','K','Si']]
z=np.abs(zscore(out_col))
z
# Out:
#            RI        Na        Ba        Ca        Fe        Al         K  \
# 0    0.245101  0.591880  0.353808  0.792599  0.588301  0.173500  0.029329
# 1    0.716826  0.150946  0.353808  0.827734  0.588301  0.187433  0.167472
# 2    0.228607  0.240996  0.353808  0.518546  0.588301  0.313863  0.108813
# 3    0.307777  0.167507  0.353808  0.623951  0.588301  0.414122  0.078115
# 4    0.789399  0.755419  0.353808  0.623951  2.082200  0.347848  0.216258
# ..        ...       ...       ...       ...       ...       ...       ...
# 208  0.700332  0.898085  1.778672  0.156046  0.588301  2.874379  0.643296
# 209  0.495808  1.853443  2.844912  0.392060  0.588301  1.089766  0.766090
# 210  0.757727  1.167545  2.945501  0.363952  0.588301  1.149921  0.766090
# 211  0.607966  1.192041  2.804676  0.335844  0.588301  0.989506  0.766090
# 212  0.410039  1.008318  3.005854  0.237466  0.588301  1.270232  0.766090
#
#            Si
# 0    0.097091
# 1    0.433777
# 2    0.058303
# 3    0.550322
# ...

# %%
#threesold=3
np.where(z>3)
# Out:
# (array([104, 105, 105, 105, 105, 105, 106, 106, 106, 109, 110, 111, 111,
#         130, 144, 161, 162, 162, 162, 170, 170, 171, 171, 173, 183, 183,
#         187, 188, 200, 200, 202, 206, 212], dtype=int64),
#  array([3, 0, 1, 2, 3, 7, 0, 3, 7, 3, 3, 0, 3, 3, 4, 4, 2, 5, 7, 5, 6, 5,
#         6, 4, 1, 7, 7, 2, 6, 7, 2, 2, 2], dtype=int64))

# %%
z.iloc[104,3]
# Out:
# 3.00900736343217

# %%
#removoing the dataabove zscore and creating new df
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (193, 10)

# %%
#shape of old and new data
print("old data frame.--",df.shape[0])
print("new data frame.--",df1.shape[0])
# Out:
# old data frame.-- 213
# new data frame.-- 193

# %%
print("data loss percentage--", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage-- 9.389671361502346

# %%
df1
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type of glass
# 0    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.00              1
# 1    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.00              1
# 2    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.00              1
# 3    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00              1
# 4    1.51596  12.79  3.61  1.62  72.97  0.64  8.07  0.00  0.26              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...            ...
# 207  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.00              7
# 208  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.00              7
# 209  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.00              7
# 210  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.00              7
# 211  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.00              7
#
# [193 rows x 10 columns]

# %%
df=df1

# %%
#lets check how data hss been distributed in remaing column-checking the column with inthe column
plt.figure(figsize=(20,15), facecolor= "white")
plotnumber = 1#iteration or index value
for col in df:
    if plotnumber<=11:
        ax=plt.subplot(4,3, plotnumber)#subplot is used to plot diff plot on single image
        sns.boxplot(df[col], color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation= 0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# our dataset has low data we cant lose more than 10% of data.

# %%
#checking skewness
df.skew()
# Out:
# RI               0.971729
# Na               0.375857
# Mg              -1.533664
# Al               0.649917
# Si              -0.436288
# K                0.297900
# Ca               1.074092
# Ba               3.178256
# Fe               1.478611
# Type of glass    1.277279
# dtype: float64

# %%
#removing skewness using cuberoot method the acceptable range is -0.5 to +0.5
df["Ba"]=np.cbrt(df["Ba"])
df["Mg"]=np.cbrt(df["Mg"])
df["Si"]=np.cbrt(df["Si"])
df["Fe"]=np.cbrt(df["Fe"])
df["Ca"]=np.cbrt(df["Ca"])
df["RI"]=np.cbrt(df["RI"])

# %%
df.skew()
# Out:
# RI               0.966994
# Na               0.375857
# Mg              -1.892297
# Al               0.649917
# Si              -0.459112
# K                0.297900
# Ca               0.609725
# Ba               2.198820
# Fe               0.875093
# Type of glass    1.277279
# dtype: float64

# %% [markdown]
# Ba,Mg has high skweness we can drop one column once checknwith correlataion

# %%
#by using heatmap checking the correlation matrix
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1,fmt='.1g', linecolor="black", annot=True, cmap="Blues_r")
plt.title("Correlation matrix for Type of glass")
plt.show()

# %% [markdown]
# Ba and Mg are highly correlated with each other. Going to drop one column

# %%
#check the corr
cor = df.corr()
cor
# Out:
#                      RI        Na        Mg        Al        Si         K  \
# RI             1.000000  0.048625  0.059080 -0.520317 -0.605914 -0.362602
# Na             0.048625  1.000000 -0.528150  0.254805 -0.234473 -0.612858
# Mg             0.059080 -0.528150  1.000000 -0.579002 -0.358374  0.502401
# Al            -0.520317  0.254805 -0.579002  1.000000  0.332427  0.000847
# Si            -0.605914 -0.234473 -0.358374  0.332427  1.000000  0.063462
# K             -0.362602 -0.612858  0.502401  0.000847  0.063462  1.000000
# Ca             0.693928  0.018073 -0.389498 -0.222600 -0.162629 -0.529334
# Ba            -0.224409  0.548616 -0.650990  0.598833  0.180766 -0.298576
# Fe             0.020865 -0.159948  0.113416 -0.086766 -0.002994  0.047945
# Type of glass -0.163100  0.535440 -0.781817  0.659242  0.257096 -0.391378
#
#                      Ca        Ba        Fe  Type of glass
# RI             0.693928 -0.224409  0.020865      -0.163100
# ...

# %% [markdown]
# Label Encoding---we can see labels has 6 categories 1,2,3,5,6,7..but we want see only 2 categories window glass as '1' and Non window glass  '2'..so we divide into two particular values like if values is equal to 5 and greater than 5 replace with '1', and remaining 4 and lessthan 4 replace with '0'

# %% [markdown]
# # Seperating the label and features¶

# %%
x=df.drop('Type of glass', axis=1)
y=df["Type of glass"]

# %%
print(x)
print(y)
# Out:
#            RI     Na        Mg    Al        Si     K        Ca        Ba  \
# 0    1.149176  13.89  1.532619  1.36  4.174180  0.48  1.985732  0.000000
# 1    1.148815  13.53  1.525490  1.54  4.179148  0.39  1.981496  0.000000
# 2    1.149189  13.21  1.545286  1.29  4.171883  0.57  2.018168  0.000000
# 3    1.149129  13.27  1.535452  1.24  4.180865  0.55  2.005816  0.000000
# 4    1.148760  12.79  1.534037  1.62  4.178767  0.64  2.005816  0.000000
# ..        ...    ...       ...   ...       ...   ...       ...       ...
# 207  1.148871  14.37  0.000000  2.74  4.176475  0.00  2.114190  0.814325
# 208  1.148828  14.14  0.000000  2.88  4.171883  0.08  2.093860  1.019613
# 209  1.148985  14.92  0.000000  1.99  4.180484  0.00  2.032793  1.167165
# 210  1.149943  14.36  0.000000  2.02  4.187339  0.00  2.036014  1.179274
# 211  1.148899  14.38  0.000000  1.94  4.190948  0.00  2.039226  1.162251
#
#           Fe
# 0    0.00000
# 1    0.00000
# 2    0.00000
# 3    0.00000
# 4    0.63825
# ...

# %%
y=df['Type of glass'].apply(lambda y_value: 1 if y_value>=5 else 0)

# %%
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 207    1
# 208    1
# 209    1
# 210    1
# 211    1
# Name: Type of glass, Length: 193, dtype: int64

# %%
print(y.value_counts())
# Out:
# 0    153
# 1     40
# Name: Type of glass, dtype: int64

# %% [markdown]
# we can see there is a class imbalance

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0   -0.191086  0.704498  0.484188 -0.145324  0.010415  0.165576 -1.035703
# 1   -0.819321  0.169658  0.470877  0.260836  0.456906 -0.154697 -1.091935
# 2   -0.169126 -0.305754  0.507839 -0.303276 -0.196017  0.485849 -0.605107
# 3   -0.274535 -0.216615  0.489477 -0.416098  0.611214  0.414677 -0.769075
# 4   -0.916007 -0.929734  0.486835  0.441351  0.422598  0.734950 -0.769075
# ..        ...       ...       ...       ...       ...       ...       ...
# 188 -0.722643  1.417617 -2.377492  2.968571  0.216620 -1.542547  0.669606
# 189 -0.797348  1.075914 -2.377492  3.284473 -0.196017 -1.257860  0.399720
# 190 -0.524924  2.234732 -2.377492  1.276236  0.576934 -1.542547 -0.410958
# 191  1.143153  1.402760 -2.377492  1.343930  1.193013 -1.542547 -0.368191
# 192 -0.674308  1.432473 -2.377492  1.163414  1.517354 -1.542547 -0.325559
#
#            Ba        Fe
# 0   -0.416569 -0.680595
# 1   -0.416569 -0.680595
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["VIF values"]=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"]=x.columns
vif
# Out:
#    VIF values Features
# 0    5.134297       RI
# 1    7.830542       Na
# 2   14.961313       Mg
# 3    3.514577       Al
# 4    5.620756       Si
# 5    4.268378        K
# 6   10.435650       Ca
# 7    3.634567       Ba
# 8    1.054794       Fe

# %% [markdown]
# 1)Mg has highest vif value..so we can drop it.

# %%
# !pip install imblearn
from imblearn.over_sampling import SMOTE
SM=SMOTE()
x1,y1=SM.fit_resample(x,y)

# %%
y1.value_counts()
# Out:
# 0    153
# 1    153
# Name: Type of glass, dtype: int64

# %% [markdown]
# DATA SET IS BALANCED

# %% [markdown]
# # DATA MODELLING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix, roc_curve, roc_auc_score,recall_score ,classification_report, f1_score, precision_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
x_train, x_test, y_train, y_test = train_test_split(x1,y1, test_size=0.25, random_state=2)

# %%
models={"LogisticRegression":LogisticRegression(),
         "AdaBoostClassifier":AdaBoostClassifier(),
          "GradientBoostingClassifier":GradientBoostingClassifier(),"BaggingClassifier":BaggingClassifier(),
           "RandomForestClassifier":RandomForestClassifier(),
             "support vector mach":SVC(),"Decision tree classifier":DecisionTreeClassifier()
       }
                                
for i in range(len(list(models))):
       model= list(models.values())[i]
       model.fit(x_train,y_train)#train model
        
        # making predictions
       y_train_pred = model.predict(x_train)
       y_test_pred =model.predict(x_test)
        
        
        #Training set performance
       model_train_accuracy = accuracy_score(y_train,y_train_pred)
       model_train_f1    =   f1_score(y_train,y_train_pred)
       model_train_precision = precision_score(y_train,y_train_pred)
       model_train_recall =   recall_score(y_train,y_train_pred)
       model_train_roauc_score= roc_auc_score(y_train,y_train_pred)    
       #model_train_classification_report= classification_report(y_train,y_train_pred) 
                                        
                                        
          #Test set performance
       model_test_accuracy = accuracy_score(y_test,y_test_pred)
       model_test_f1    =   f1_score(y_test,y_test_pred)
       model_test_precision = precision_score(y_test,y_test_pred)
       model_test_recall =   recall_score(y_test,y_test_pred)
       model_test_roauc_score= roc_auc_score(y_test,y_test_pred)    
       #model_test_classification_report= classification_report(y_train,y_train_pred)   
        
                                         
       print(list(models.keys())[i]) 
                                        
                                        
       print("Model performance for Training set")
       print("-- Accuracy: {:.4f}".format(model_train_accuracy))       
       print("-- F1: {:.4f}".format(model_train_f1))                                 
       print("-- Precision: {:.4f}".format(model_train_precision))                                 
       print("-- Recalll: {:.4f}".format(model_train_recall))                                 
      
                                     
                                     
                                        
                                        
       print("Model performance for Test set")
       print("-- Accuracy: {:.4f}".format(model_test_accuracy))       
       print("-- F1: {:.4f}".format(model_test_f1))                                 
       print("-- Precision: {:.4f}".format(model_test_precision))                                 
       print("-- Recalll: {:.4f}".format(model_test_recall))                                 
       
                                        
       print('-'*30) 
       print("\n")
# Out:
# LogisticRegression
# Model performance for Training set
# -- Accuracy: 0.9738
# -- F1: 0.9735
# -- Precision: 0.9735
# -- Recalll: 0.9735
# Model performance for Test set
# -- Accuracy: 0.9351
# -- F1: 0.9351
# -- Precision: 0.9730
# -- Recalll: 0.9000
# ------------------------------
#
#
# AdaBoostClassifier
# Model performance for Training set
# -- Accuracy: 1.0000
# -- F1: 1.0000
# -- Precision: 1.0000
# -- Recalll: 1.0000
# Model performance for Test set
# -- Accuracy: 0.9610
# -- F1: 0.9620
# -- Precision: 0.9744
# -- Recalll: 0.9500
# ------------------------------
#
#
# GradientBoostingClassifier
# Model performance for Training set
# -- Accuracy: 1.0000
# -- F1: 1.0000
# -- Precision: 1.0000
# -- Recalll: 1.0000
# Model performance for Test set
# -- Accuracy: 0.9481
# -- F1: 0.9487
# -- Precision: 0.9737
# -- Recalll: 0.9250
# ------------------------------
#
#
# BaggingClassifier
# Model performance for Training set
# -- Accuracy: 1.0000
# -- F1: 1.0000
# ...

# %% [markdown]
# NO much difference in training and test score seems like no OVERFITTIG.

# %%
models=[LogisticRegression(),AdaBoostClassifier(),GradientBoostingClassifier(),SVC(),BaggingClassifier(),RandomForestClassifier(),DecisionTreeClassifier()]

# %%
def compare_models_cross_validation():
    
    for model in models:
        
        cv_score = cross_val_score(model, x, y, cv=5)
        mean_accuracy = sum(cv_score)/len(cv_score)
        mean_accuracy = mean_accuracy*100
        
        
        print('Cross Validation Score for the', model, '=', cv_score)
        print('Mean Accuracy  of the', model, '=', mean_accuracy,'%')
        print('-'*30) 
        print("\n")

# %%
compare_models_cross_validation()
# Out:
# Cross Validation Score for the LogisticRegression() = [0.87179487 0.82051282 0.8974359  0.89473684 0.97368421]
# Mean Accuracy  of the LogisticRegression() = 89.16329284750339 %
# ------------------------------
#
#
# Cross Validation Score for the AdaBoostClassifier() = [0.82051282 0.92307692 0.8974359  0.92105263 0.97368421]
# Mean Accuracy  of the AdaBoostClassifier() = 90.71524966261808 %
# ------------------------------
#
#
# Cross Validation Score for the GradientBoostingClassifier() = [0.79487179 0.8974359  0.8974359  0.92105263 0.97368421]
# Mean Accuracy  of the GradientBoostingClassifier() = 89.68960863697706 %
# ------------------------------
#
#
# Cross Validation Score for the SVC() = [0.84615385 0.84615385 0.8974359  0.94736842 0.97368421]
# Mean Accuracy  of the SVC() = 90.21592442645074 %
# ------------------------------
#
#
# Cross Validation Score for the BaggingClassifier() = [0.84615385 0.84615385 0.8974359  0.86842105 0.97368421]
# ...

# %% [markdown]
# Model selection

# %% [markdown]
# THE LOWEST SCORE DIFFERENCE BETWEEN THE MODEL AND CROSS VALIDATION SCORE IS THE BEST MODEL

# %%
#difference between models and cross validation score
print("Diff between Accuracy score and cross_validation score  for logistic regression is =",  93.51 -89.16)
print("Diff between Accuracy score and cross_validation score  for AdaBoostClassifier is =",   96.10 -90.71)
print("Diff between Accuracy score and cross_validation score  for GradientBoostingClassifier is =",  94.81 -89.68)
print("Diff between Accuracy score and cross_validation score  for BaggingClassifier is =",  96.10 -88.63)
print("Diff between Accuracy score and cross_validation score  for RandomForestClassifier is =",  97.40-89.16)
print("Diff between Accuracy score and cross_validation score  for DecisionTreeClassifier is =", 94.81 -91.76)
print("Diff between Accuracy score and cross_validation score  for support vector machine is =", 97.4 -90.21)
# Out:
# Diff between Accuracy score and cross_validation score  for logistic regression is = 4.3500000000000085
# Diff between Accuracy score and cross_validation score  for AdaBoostClassifier is = 5.390000000000001
# Diff between Accuracy score and cross_validation score  for GradientBoostingClassifier is = 5.1299999999999955
# Diff between Accuracy score and cross_validation score  for BaggingClassifier is = 7.469999999999999
# Diff between Accuracy score and cross_validation score  for RandomForestClassifier is = 8.240000000000009
# Diff between Accuracy score and cross_validation score  for DecisionTreeClassifier is = 3.049999999999997
# Diff between Accuracy score and cross_validation score  for support vector machine is = 7.190000000000012

# %% [markdown]
# Decision TRee is the best model because it has less difference between Model accuracy and Validation score

# %% [markdown]
# HYPER PARAMETER TUNING-

# %%
from sklearn.model_selection import RandomizedSearchCV

parameters ={'criterion':['entropy','gini'],
             'splitter':['best', 'random'],
             'min_samples_split':[1,2],
             'max_depth' : [0,10,20],
             'min_samples_leaf':[0,1],
             'class_weight':[None],
             'min_impurity_decrease' :[0.0],
             'max_leaf_nodes':[int,None],
             'random_state':[10,50,100]
             }

# %%
DCV=RandomizedSearchCV(DecisionTreeClassifier(),parameters,cv=5)

# %%
DCV.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#                    param_distributions={'class_weight': [None],
#                                         'criterion': ['entropy', 'gini'],
#                                         'max_depth': [0, 10, 20],
#                                         'max_leaf_nodes': [<class 'int'>, None],
#                                         'min_impurity_decrease': [0.0],
#                                         'min_samples_leaf': [0, 1],
#                                         'min_samples_split': [1, 2],
#                                         'random_state': [10, 50, 100],
#                                         'splitter': ['best', 'random']})

# %%
DCV.best_params_
# Out:
# {'splitter': 'best',
#  'random_state': 100,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'min_impurity_decrease': 0.0,
#  'max_leaf_nodes': None,
#  'max_depth': 10,
#  'criterion': 'entropy',
#  'class_weight': None}

# %%
final_model=DecisionTreeClassifier(criterion='entropy',splitter='best',min_samples_split=2,min_samples_leaf=1,
                                   max_leaf_nodes=None,max_depth=20,min_impurity_decrease=0.0,random_state=100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc= accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 92.20779220779221

# %%
from sklearn.model_selection import GridSearchCV

parameters ={'criterion':['entropy','gini'],
             'splitter':['best', 'random'],
             'min_samples_split':[1,2],
             'max_depth' : [0,10,20],
             'min_samples_leaf':[0,1],
             'class_weight':[None],
             'min_impurity_decrease' :[0.0],81
             'max_leaf_nodes':[int,None],'random_state':[10,50,100,150]
             }

# %%
DTV=GridSearchCV(DecisionTreeClassifier(),parameters,cv=5)

# %%
DTV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'class_weight': [None],
#                          'criterion': ['entropy', 'gini'],
#                          'max_depth': [0, 10, 20],
#                          'max_leaf_nodes': [<class 'int'>, None],
#                          'min_impurity_decrease': [0.0],
#                          'min_samples_leaf': [0, 1],
#                          'min_samples_split': [1, 2],
#                          'random_state': [10, 50, 100, 150],
#                          'splitter': ['best', 'random']})

# %%
DTV.best_params_
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 10,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 1,
#  'random_state': 100,
#  'splitter': 'best'}

# %%
final_model=DecisionTreeClassifier(criterion='gini',splitter='best',min_samples_split=1,min_samples_leaf=1,
                                   max_leaf_nodes=None,max_depth=10,min_impurity_decrease=0.0,random_state=100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc= accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 92.20779220779221

# %% [markdown]
# After performing hyperparameter tuning there is a decrease in accuracy score from 94.81 to 92.20

# %% [markdown]
# PLOTTING ROC AND compare AUC FOR ALL MODELS

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn import model_selection
from sklearn import metrics
fpr,tpr, thresholds=metrics.roc_curve(y_test, pred)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc,estimator_name=final_model)
display.plot()

# %% [markdown]
# Here we have plotted the ROC curve for the final model and the AUC value for the best model is 92%

# %%
#saving model using .pkl
import joblib
joblib.dump(final_model,"Glass-quality.pkl")
# Out:
# ['Glass-quality.pkl']
