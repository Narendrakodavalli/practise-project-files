# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing data set¶

# %%
df=pd.read_csv('happiness_score_dataset.csv')

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# # EDA EXPLORATARY DATA ANALYSIS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# 1)No null values are present
# 2)datatypes are correct

# %%
#checking null values
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# 1)Outliers are present in GDP,TRUST,GENEROSITY,family columns.

# %%
#seperating the numerical and categorical columns

#checking the Categorical columns
Categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i] =="object": 
        Categorical_col.append(i)
 
print("Categorical columns:  ",Categorical_col)
print("\n")


Numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i] !="object": 
        Numerical_col.append(i)
 
print("Numerical columns:  ",Numerical_col)
print("\n")
# Out:
# Categorical columns:   ['Country', 'Region']
#
#
# Numerical columns:   ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# # DATA VISULIZATION

# %% [markdown]
# univariate analysis

# %%
#Distribution of target happiness score column
plt.figure(figsize=(6,6))
sns.distplot(df['Happiness Score'])
plt.title("Happiness DISTRIBUTION")
plt.show()

# %%
#finding average happiness score
df["Happiness Score"].mean()
# Out:
# 5.375734177215189

# %% [markdown]
# Bi-varaite analysis

# %%
#comparing happiness score with Economy (GDP per Capita)
plt.figure(figsize=(15,7), facecolor= "white")
sns.scatterplot(x='Happiness Score', y='Economy (GDP per Capita)', data=df, hue=df.Region)
plt.title('Happiness score vs GDP')
plt.legend(loc = "upper left", fontsize ='10')
plt.xlabel('Happiness Score')
plt.ylabel('Economy (GDP per Capita)')
# Out:
# Text(0, 0.5, 'Economy (GDP per Capita)')

# %% [markdown]
# 1)Happiness score and economy are directly proportional to each other 2)above plot clearly shows that happinessscore is less in sub-saharan africa countries and more in western europe.

# %%
#comparing happiness score with Health (Life Expectancy)
#sns.scatterplot(x='Happiness Score', y='Health (Life Expectancy)', data=df)
#plt.title('Health (Life Expectancy) vs Happiness score')
plt.figure(figsize=(15,7), facecolor= "white")
sns.scatterplot(x='Happiness Score', y='Health (Life Expectancy)', data=df, hue=df.Region)
plt.title('Happiness score vs Health (Life Expectancy)')
plt.legend(loc = "upper left", fontsize ='10')
plt.xlabel('Happiness Score')
plt.ylabel('Health (Life Expectancy)')
# Out:
# Text(0, 0.5, 'Health (Life Expectancy)')

# %% [markdown]
# 1)Happiness score and health life expectancy are directly proportional to each other in most of times

# %%
#comparing happiness score with Health (Life Expectancy)
sns.scatterplot(x='Freedom', y='Happiness Score', data=df)
plt.title('Freedom vs Happiness score')
# Out:
# Text(0.5, 1.0, 'Freedom vs Happiness score')

# %%
#comparing happiness score with Health (Life Expectancy)
sns.scatterplot(x='Trust (Government Corruption)', y='Happiness Score', data=df)
plt.title('Trust (Government Corruption) vs Happiness score')
# Out:
# Text(0.5, 1.0, 'Trust (Government Corruption) vs Happiness score')

# %%
plt.figure(figsize=(15,7), facecolor= "white")
sns.scatterplot(x='Happiness Score', y='Trust (Government Corruption)', data=df, hue=df.Region)
plt.title('Happiness score vs Trust (Government Corruption)')
plt.legend(loc = "upper left", fontsize ='10')
plt.xlabel('Happiness Score')
plt.ylabel('Trust (Government Corruption)')
# Out:
# Text(0, 0.5, 'Trust (Government Corruption)')

# %%
#comparing happiness score with Health (Life Expectancy)
sns.scatterplot(x='Generosity', y='Happiness Score', data=df)
plt.title('Generosity vs Happiness score')
# Out:
# Text(0.5, 1.0, 'Generosity vs Happiness score')

# %%
plt.figure(figsize=(15,7), facecolor= "white")
sns.scatterplot(x='Happiness Score', y='Generosity', data=df, hue=df.Region)
plt.title('Happiness score vs Generosity')
plt.legend(loc = "upper left", fontsize ='10')
plt.xlabel('Happiness Score')
plt.ylabel('Generosity')
# Out:
# Text(0, 0.5, 'Generosity')

# %%
#comparing happiness score with Economy (GDP per Capita)
plt.figure(figsize=(15,7), facecolor= "white")
sns.scatterplot(x='Happiness Score', y='Dystopia Residual', data=df, hue=df.Region)
plt.title('Happiness score vs Dystopia Residual')
plt.legend(loc = "upper left", fontsize ='10')
plt.xlabel('Happiness Score')
plt.ylabel('Dystopia Residual')
# Out:
# Text(0, 0.5, 'Dystopia Residual')

# %% [markdown]
# Happiness score and GDP are directly proportional to each other

# %%
#comparing happiness score with Family
sns.scatterplot(x='Happiness Score', y='Family', data=df)
plt.title('Family vs Happiness score')
# Out:
# Text(0.5, 1.0, 'Family vs Happiness score')

# %% [markdown]
# Happiness score and family are directly proportional to each other

# %%
dis_re=df.loc[df["Dystopia Residual"] > 1.850, "Country"]
print(dis_re)
# Out:
# 0                   Switzerland
# 1                       Iceland
# 2                       Denmark
# 3                        Norway
# 4                        Canada
#                  ...
# 146                  Madagascar
# 147    Central African Republic
# 148                        Chad
# 149                      Guinea
# 152                 Afghanistan
# Name: Country, Length: 112, dtype: object

# %%
df=df.drop("Happiness Rank", axis=1)

# %%
#pair plot for featues
sns.pairplot(data=df,palette="dark2")

# %%
#check the correlation
cor = df.corr()
cor
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
#by using heatmap checking the correlation matrix
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(), linewidths=0.1,fmt='.1g', linecolor="black", annot=True, cmap="Blues_r")
plt.title("Correlation matrix for Happiness score")
plt.show()

# %% [markdown]
# # Encoding the categorical columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
df["Region"]=le.fit_transform(df["Region"])
df["Country"]=le.fit_transform(df["Country"])
df.head()
# Out:
#    Country  Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0      135       9            7.587         0.03411                   1.39651
# 1       58       9            7.561         0.04884                   1.30232
# 2       37       9            7.527         0.03328                   1.32548
# 3      105       9            7.522         0.03880                   1.45900
# 4       24       5            7.427         0.03553                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %% [markdown]
# Detectiong the Outliers

# %%
plt.figure(figsize=(20,15), facecolor= "white")
plotnumber = 1#iteration or index value
for col in df:
    if plotnumber<=13:
        ax=plt.subplot(4,3, plotnumber)
        sns.boxplot(df[col])
        plt.xlabel(col,fontsize=12)
       
    plotnumber+=1
plt.tight_layout()

# %%
from scipy.stats import zscore
out_col=df[['Trust (Government Corruption)','Standard Error','Generosity','Family']]
z=np.abs(zscore(out_col))#abs= if there is any neg value converting intopositive
z
# Out:
#      Trust (Government Corruption)  Standard Error  Generosity    Family
# 0                         2.309652        0.805926    0.471040  1.320281
# 1                         0.016480        0.055889    1.575856  1.514458
# 2                         2.842774        0.854487    0.824293  1.361054
# 3                         1.852081        0.531526    0.868638  1.251922
# 4                         1.555725        0.722845    1.748563  1.221204
# ..                             ...             ...         ...       ...
# 153                       3.413922        0.774917    0.087228  0.800520
# 154                       0.529210        0.662582    0.433117  2.346860
# 155                       0.381419        0.132534    1.856891  1.901086
# 156                       0.357715        2.263962    0.316950  2.118467
# 157                       0.301803        1.134182    0.558153  3.134725
#
# [158 rows x 4 columns]

# %%
#threesold=3
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 157], dtype=int64),
#  array([0, 1, 1, 1, 2, 3, 0, 3], dtype=int64))

# %%
z.iloc[27,0]
# Out:
# 3.1646194851713774

# %%
#removoing the dataabove zscore and creating new df
df1=df[(z<3).all(axis=1)]
df1.shape
# Out:
# (150, 11)

# %%
#shape of old and new data
print("old data frame.--",df.shape[0])
print("new data frame.--",df1.shape[0])
# Out:
# old data frame.-- 158
# new data frame.-- 150

# %%
print("data loss percentage--", ((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage-- 5.063291139240507

# %%
df1
# Out:
#      Country  Region  Happiness Score  Standard Error  \
# 0        135       9            7.587         0.03411
# 1         58       9            7.561         0.04884
# 2         37       9            7.527         0.03328
# 3        105       9            7.522         0.03880
# 4         24       5            7.427         0.03553
# ..       ...     ...              ...             ...
# 151       20       8            3.587         0.04324
# 152        0       7            3.575         0.03084
# 154       13       8            3.340         0.03656
# 155      136       4            3.006         0.05015
# 156       21       8            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df=df1

# %%
#lets check how data hss been distributed in remaing column-checking the column with inthe column
plt.figure(figsize=(20,15), facecolor= "white")
plotnumber = 1#iteration or index value
for col in df:
    if plotnumber<=11:
        ax=plt.subplot(4,3, plotnumber)#subplot is used to plot diff plot on single image
        sns.distplot(df[col], color="m")
        plt.xlabel(col,fontsize=12)
        plt.yticks(rotation= 0, fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %%
#checking skewness
df.skew()
# Out:
# Country                          0.036418
# Region                          -0.090245
# Happiness Score                  0.138125
# Standard Error                   1.240644
# Economy (GDP per Capita)        -0.381407
# Family                          -0.798605
# Health (Life Expectancy)        -0.755919
# Freedom                         -0.391806
# Trust (Government Corruption)    1.266162
# Generosity                       0.644088
# Dystopia Residual               -0.195486
# dtype: float64

# %%
#removing skewness using cuberoot method the acceptable range is -0.5 to +0.5
df["Standard Error"]=np.cbrt(df["Standard Error"])
df["Trust (Government Corruption)"]=np.cbrt(df["Trust (Government Corruption)"])

# %%
x=df1.drop("Happiness Score", axis=1)
y=df1["Happiness Score"]

print("Feature dimensin--", x.shape)
print("label dimension--", y.shape)
# Out:
# Feature dimensin-- (150, 10)
# label dimension-- (150,)

# %%
df.skew()
# Out:
# Country                          0.036418
# Region                          -0.090245
# Happiness Score                  0.138125
# Standard Error                   0.521955
# Economy (GDP per Capita)        -0.381407
# Family                          -0.798605
# Health (Life Expectancy)        -0.755919
# Freedom                         -0.391806
# Trust (Government Corruption)   -0.075835
# Generosity                       0.644088
# Dystopia Residual               -0.195486
# dtype: float64

# %% [markdown]
# feature scaling using standardscalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)# after the scaling the output in arrarys so keep in dataframe
x
# Out:
#       Country    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0    1.256925  1.303018       -0.916267                  1.388762  1.356364
# 1   -0.425091  1.303018        0.287795                  1.144569  1.563966
# 2   -0.883823  1.303018       -0.993734                  1.204613  1.399956
# 3    0.601594  1.303018       -0.500608                  1.550771  1.283278
# 4   -1.167800 -0.024335       -0.786597                  1.206713  1.250437
# ..        ...       ...             ...                       ...       ...
# 145 -1.255177  0.971180       -0.136953                 -1.562576 -0.603215
# 146 -1.692064  0.639341       -1.229202                 -1.402615 -2.765197
# 147 -1.408088  0.971180       -0.694688                 -1.488610 -2.564329
# 148  1.278769 -0.356173        0.382415                 -0.512384 -2.087734
# 149 -1.233333  0.971180        2.532796                 -2.192100 -2.320145
#
# ...

# %% [markdown]
# DATA MODELLING

# %% [markdown]
# Creating train test split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.30, random_state=20)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge

# %%
models=[LinearRegression(),DecisionTreeRegressor(),KNN(),RandomForestRegressor(),
        GradientBoostingRegressor(),SVR()]

# %%
def r2score_train_test():
    
    for model in models:
        model.fit(x_train,y_train)
        y_train_pred = model.predict(x_train)
        y_test_pred =model.predict(x_test)
        
        
    
        print(model)
        print('r2 Score for the training',  '=', r2_score(y_train,y_train_pred)*100)
        print('r2 Score for the testing', '=',  r2_score(y_test,y_test_pred)*100)
        print('Mean Absolute Error:',  '=',  mean_absolute_error(y_test,y_test_pred))
        print('Mean squared Error:', '=',  mean_squared_error(y_test,y_test_pred))
        print('Root Mean square Error:', '=',   np.sqrt(mean_squared_error(y_test,y_test_pred))) 
        print('-'*30)  
        print("\n")

# %%
r2score_train_test()
# Out:
# LinearRegression()
# r2 Score for the training = 99.88334916391803
# r2 Score for the testing = 99.92807851075766
# Mean Absolute Error: = 0.02355336469228587
# Mean squared Error: = 0.000893521873114083
# Root Mean square Error: = 0.02989183622854379
# ------------------------------
#
#
# DecisionTreeRegressor()
# r2 Score for the training = 100.0
# r2 Score for the testing = 70.36877487847141
# Mean Absolute Error: = 0.4823111111111112
# Mean squared Error: = 0.3681256888888891
# Root Mean square Error: = 0.6067336226787576
# ------------------------------
#
#
# KNeighborsRegressor()
# r2 Score for the training = 91.6331429653831
# r2 Score for the testing = 86.04934039659126
# Mean Absolute Error: = 0.3290933333333333
# Mean squared Error: = 0.17331703822222214
# Root Mean square Error: = 0.4163136296378274
# ------------------------------
#
#
# RandomForestRegressor()
# r2 Score for the training = 98.54434882154138
# r2 Score for the testing = 91.86294633834642
# ...

# %% [markdown]
# Model selection

# %% [markdown]
# For these particular data we are selecting the SVR is the best model because the test score is good and MAE is low when compared to other model

# %% [markdown]
# # HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters ={ 'alpha':[0.0,0.1],
             'min_samples_leaf':[1,2], 
              'min_samples_split':[1,2],
              'learning_rate':[0.01,0.1],'n_estimators':[10,50,100],'max_depth':[2,3,5],
             'min_impurity_decrease':[0.0,0.1],'random_state':[None],'loss':['squared_error','absolute_error','huber'],
             'criterion':['friedman_mse','squared_error'],'subsample':[0.0,0.1],'min_weight_fraction_leaf':[0.0,0.5],
            }

# %%
GCV=GridSearchCV(GradientBoostingRegressor(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'alpha': [0.0, 0.1],
#                          'criterion': ['friedman_mse', 'squared_error'],
#                          'learning_rate': [0.01, 0.1],
#                          'loss': ['squared_error', 'absolute_error', 'huber'],
#                          'max_depth': [2, 3, 5],
#                          'min_impurity_decrease': [0.0, 0.1],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [1, 2],
#                          'min_weight_fraction_leaf': [0.0, 0.5],
#                          'n_estimators': [10, 50, 100], 'random_state': [None],
#                          'subsample': [0.0, 0.1]})

# %%
GCV.best_params_
# Out:
# {'alpha': 0.1,
#  'criterion': 'friedman_mse',
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 5,
#  'min_impurity_decrease': 0.1,
#  'min_samples_leaf': 1,
#  'min_samples_split': 1,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'random_state': None,
#  'subsample': 0.1}

# %%
final_model=GradientBoostingRegressor(criterion='friedman_mse', max_depth= 5, n_estimators=100,  
random_state=10,alpha=0.1,loss='squared_error',min_samples_leaf=1,min_samples_split=1,subsample=0.1,min_impurity_decrease=0.1)
final_model.fit(x_train,y_train)
y_train_pred = final_model.predict(x_train)
y_test_pred =final_model.predict(x_test)
print(r2_score(y_test,y_test_pred)*100)
# Out:
# 93.80330925220572

# %% [markdown]
# There is aincrease in prediction score from 92.7 to 93.8

# %%
#saving model using .pkl
import joblib
joblib.dump(final_model ,"happines_report.pkl")
# Out:
# ['happines_report.pkl']
